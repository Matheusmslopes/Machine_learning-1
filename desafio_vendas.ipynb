# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
dados_vendas = {
    'mes': [
      'Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho',  'Julho', 'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro'
    ],
    'vendas': [
       2000, 2200, 2300, 2500, 2600, 2700,
       2800, 2900, 3000, 3100, 3200, 3300
    ]
}

# %%
df_vendas = pd.DataFrame(dados_vendas)
df_vendas
# Out:
#           mes  vendas
# 0     Janeiro    2000
# 1   Fevereiro    2200
# 2       Março    2300
# 3       Abril    2500
# 4        Maio    2600
# 5       Junho    2700
# 6       Julho    2800
# 7      Agosto    2900
# 8    Setembro    3000
# 9     Outubro    3100
# 10   Novembro    3200
# 11   Dezembro    3300

# %%
df_vendas.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   mes     12 non-null     str
#  1   vendas  12 non-null     int64
# dtypes: int64(1), str(1)
# memory usage: 324.0 bytes

# %%
df_vendas['mes_numero'] = range(1, 13)

# %%
df_vendas
# Out:
#           mes  vendas  mes_numero
# 0     Janeiro    2000           1
# 1   Fevereiro    2200           2
# 2       Março    2300           3
# 3       Abril    2500           4
# 4        Maio    2600           5
# 5       Junho    2700           6
# 6       Julho    2800           7
# 7      Agosto    2900           8
# 8    Setembro    3000           9
# 9     Outubro    3100          10
# 10   Novembro    3200          11
# 11   Dezembro    3300          12

# %%
X = df_vendas[['mes_numero']]
y = df_vendas['vendas']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.8, random_state=42)

# %%
model = LinearRegression().fit(X_train, y_train)

# %%
y_pred = model.predict(X_test)

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 6000.0

# %%
r2_score(y_test, y_pred)
# Out:
# 0.9666851749028318

# %%
model.coef_
# Out:
# array([100.])

# %%
model.intercept_
# Out:
# np.float64(2100.0)

# %%
model.predict([[12]])
# Out:
# c:\Users\Usuario\.virtualenvs\Modelo_diabetes-lYNcUA3J\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3300.])

# %%
df_vendas.hist()
# Out:
# array([[<Axes: title={'center': 'vendas'}>,
#         <Axes: title={'center': 'mes_numero'}>]], dtype=object)

# %%
plt.scatter(X_test, y_test)
plt.plot(X_test, y_pred, color = 'k')
